# %% [markdown]
# # Sparse-view Gaussian Splatting (Colab)
#
# **Setup order:** Clone repo → Clone gaussian-splatting *with submodules* → Install `requirements-colab.txt` → Install CUDA extensions from submodules (single `cd ... && pip install` so paths are correct). Configs use no `antialiasing` to avoid rasterizer version mismatch.

# %%
# !git clone https://github.com/alifakbarhafiz/Sparse_Splats.git /content/Sparse_Splats
# %cd /content/Sparse_Splats
# Out:
# Cloning into '/content/Sparse_Splats'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 20 (delta 3), reused 20 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 11.67 KiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/Sparse_Splats

# %%
# %cd /content/Sparse_Splats
# Out:
# /content/Sparse_Splats

# %%
# Clone with submodules so diff-gaussian-rasterization and simple-knn are available
# !git clone --recurse-submodules https://github.com/graphdeco-inria/gaussian-splatting.git external/gaussian-splatting
# Out:
# /content/Sparse_Splats
# Cloning into 'external/gaussian-splatting'...
# remote: Enumerating objects: 1053, done.
# remote: Total 1053 (delta 0), reused 0 (delta 0), pack-reused 1053 (from 1)
# Receiving objects: 100% (1053/1053), 78.71 MiB | 19.31 MiB/s, done.
# Resolving deltas: 100% (593/593), done.

# %%
# Install base deps (PyTorch, etc.). CUDA extensions installed from submodules in next cell.
# !pip install -q -r requirements-colab.txt
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# Install CUDA extensions from cloned submodules (single command so cwd is correct for pip)
# !cd /content/Sparse_Splats/external/gaussian-splatting && pip install -q ./submodules/diff-gaussian-rasterization ./submodules/simple-knn
# Out:
# /bin/bash: line 1: fg: no job control
# ERROR: Invalid requirement: './submodules/diff-gaussian-rasterization': Expected package name at the start of dependency specifier
#     ./submodules/diff-gaussian-rasterization
#     ^
# Hint: It looks like a path. File './submodules/diff-gaussian-rasterization' does not exist.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir -p /content/Sparse_Splats/data/raw
# !rsync -av /content/drive/MyDrive/Datasets/NeRF_Synthetic/lego/ /content/Sparse_Splats/data/raw/lego/
# Out:
# sending incremental file list
# created directory /content/Sparse_Splats/data/raw/lego
# ./
# transforms_test.json
# transforms_train.json
# transforms_val.json
# test/
# test/r_0.png
# test/r_0_depth_0001.png
# test/r_1.png
# test/r_10.png
# test/r_100.png
# test/r_100_depth_0001.png
# test/r_101.png
# test/r_101_depth_0001.png
# test/r_102.png
# test/r_102_depth_0001.png
# test/r_103.png
# test/r_103_depth_0001.png
# test/r_104.png
# test/r_104_depth_0001.png
# test/r_105.png
# test/r_105_depth_0001.png
# test/r_106.png
# test/r_106_depth_0001.png
# test/r_107.png
# test/r_107_depth_0001.png
# test/r_108.png
# test/r_108_depth_0001.png
# test/r_109.png
# test/r_109_depth_0001.png
# test/r_10_depth_0001.png
# test/r_11.png
# test/r_110.png
# test/r_110_depth_0001.png
# test/r_111.png
# test/r_111_depth_0001.png
# test/r_112.png
# test/r_112_depth_0001.png
# test/r_113.png
# test/r_113_depth_0001.png
# test/r_114.png
# test/r_114_depth_0001.png
# test/r_115.png
# ...

# %%
# %cd /content/Sparse_Splats
# !python scripts/04_run_experiment.py \
    --raw-data-dir /content/Sparse_Splats/data/raw/lego \
    --splits-dir data/splits \
    --experiments-dir experiments/lego \
    --results-csv results/metrics.csv
# Out:
# /content/Sparse_Splats
# Running experiment defined in configs/views_10.yaml
# 2026-02-15 20:52:02.000585: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-15 20:52:02.018995: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771188722.041274   21038 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
